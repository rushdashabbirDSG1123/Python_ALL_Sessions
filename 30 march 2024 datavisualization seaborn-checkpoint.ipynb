# %% [markdown]
# # seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('empl.csv')
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(x='Salary',data=df)
# Out:
# <Axes: xlabel='Salary'>

# %%
dfbrain=pd.read_csv('headbrain.csv')
dfbrain
# Out:
#      Gender  AgeRange  HeadSize  BrainWeight
# 0         1         1      4512         1530
# 1         1         1      3738         1297
# 2         1         1      4261         1335
# 3         1         1      3777         1282
# 4         1         1      4177         1590
# ..      ...       ...       ...          ...
# 232       2         2      3214         1110
# 233       2         2      3394         1215
# 234       2         2      3233         1104
# 235       2         2      3352         1170
# 236       2         2      3391         1120
#
# [237 rows x 4 columns]

# %%
dfbrain.head(5)
# Out:
#    Gender  AgeRange  HeadSize  BrainWeight
# 0       1         1      4512         1530
# 1       1         1      3738         1297
# 2       1         1      4261         1335
# 3       1         1      3777         1282
# 4       1         1      4177         1590

# %%
sns.violinplot(x='HeadSize',data=dfbrain)
# Out:
# <Axes: xlabel='HeadSize'>

# %%
sns.violinplot(x='BrainWeight',data=dfbrain)
# Out:
# <Axes: xlabel='BrainWeight'>

# %%
dfiris=pd.read_csv('iris.csv')
dfiris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.stripplot(x='class',y='sepal length',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='sepal length'>

# %%
sns.stripplot(x='class',y='petal length',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='petal length'>

# %%
sns.stripplot(x='class',y='sepal width',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='sepal width'>

# %%
sns.stripplot(x='class',y='petal width',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='petal width'>

# %% [markdown]
# # swarm plot

# %%
sns.swarmplot(x='class',y='sepal length',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='sepal length'>

# %%
sns.swarmplot(x='class',y='sepal width',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='sepal width'>

# %%
sns.swarmplot(x='class',y='petal length',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='petal length'>

# %%
sns.swarmplot(x='class',y='petal width',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='petal width'>

# %%
#we can check how many raws are in iris setosa
dfiris['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Count plot function

# %%
sns.countplot(x='class',data=dfiris)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
# we can call dataset also which present inside the seaborn library
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
#we can take here titanic dataset
dftitanic=sns.load_dataset('titanic')
dftitanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
dftitanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
dftitanic['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
dftitanic['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='class',data=dftitanic)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(x='class',data=dftitanic)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
# catogory plot
sns.catplot(x='class',y='survived',data=dftitanic,kind='bar')

# %%
sns.catplot?

# %%
sns.catplot(x='class',y='survived',hue='sex',data=dftitanic,kind='bar')

# %%
#we can give another kind bar
sns.catplot(x='class',y='survived',hue='sex',data=dftitanic,kind='violin')

# %%
# load tips data set
dftips=sns.load_dataset('tips')
dftips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='total_bill',data=dftips)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(x='tip',data=dftips)
# Out:
# <Axes: xlabel='tip'>

# %%
dftips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(x='day',data=dftips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
dftips['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.countplot(x='smoker',data=dftips)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
#we have inside seaborn boxplot method
sns.boxplot(x='total_bill',data=dftips)
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# # distribution plot
# displot,histplot,jointplot,violinplot,rugplot

# %%
sns.histplot(x='total_bill',data=dftips,bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='tip',data=dftips,bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#displot
sns.distplot(dftips['tip'],bins=10)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(dftips['total_bill'],bins=10)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(dftips['total_bill'],bins=10,kde=False)
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# # kdeplot - kernal densityp estimation plot

# %%
sns.kdeplot(dftips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # jointplot

# %%
sns.jointplot(x='total_bill',y='tip',data=dftips)

# %% [markdown]
# # rugplot

# %%
sns.rugplot(x='tip',data=dftips)
# Out:
# <Axes: xlabel='tip'>

# %%
sns.rugplot(x='total_bill',y='tip',data=dftips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns

# %% [markdown]
# # catogorical plot

# %%
sns.boxplot(x='day',y='total_bill',data=dftips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',hue='sex',data=dftips)
# here we can checkwhos spendmore here with gender
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=dftips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(dftips)

# %%
# new data taken here 
dfmpg=sns.load_dataset('mpg')
dfmpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.scatterplot(x='mpg',y='weight',data=dfmpg)
#it wiul show negative relation
# Out:
# <Axes: xlabel='mpg', ylabel='weight'>

# %%
sns.scatterplot(x='horsepower',y='mpg',data=dfmpg)
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %% [markdown]
# # lineplot

# %%
sns.lineplot(x='weight',y='mpg',data=dfmpg)
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
sns.lineplot(x='horsepower',y='mpg',data=dfmpg)
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %% [markdown]
# # relplot relation plot

# %%
sns.relplot(x='weight',y='mpg',data=dfmpg)

# %% [markdown]
# # Regression plot

# %%
sns.regplot(x='weight',y='mpg',data=dfmpg)
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
#boxplot
sns.boxplot(x='weight',data=dfmpg)
# Out:
# <Axes: xlabel='weight'>

# %%
sns.boxplot(x='displacement',data=dfmpg)
# Out:
# <Axes: xlabel='displacement'>

# %%
#rugplot
sns.rugplot(x='weight',y='mpg',data=dfmpg)
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
#jointplot
sns.jointplot(x='weight',y='mpg',data=dfmpg)

# %%
sns.jointplot(data=dfmpg,x='weight',y='mpg', kind='kde')

# %%
sns.jointplot(data=dfmpg,x='weight',y='mpg', kind='hex')

# %%
#strip plot
sns.stripplot(data=dfmpg,x='origin',y='mpg')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
#swarm plot
sns.swarmplot(data=dfmpg,x='origin',y='mpg')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
#catplot
sns.catplot(data=dfmpg,x='origin',y='mpg',kind='box')

# %%
dftaxis=sns.load_dataset('taxis')
dftaxis
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.scatterplot(x='fare',y='distance',data=dftaxis)
# Out:
# <Axes: xlabel='fare', ylabel='distance'>

# %%
dftaxis['color'].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
sns.countplot(x='color',data= dftaxis)
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %%
dftaxis['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
sns.countplot(x='payment',data= dftaxis)
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns.stripplot(x='color',y='fare',data= dftaxis)
# Out:
# <Axes: xlabel='color', ylabel='fare'>

# %%
sns.boxplot(x='color',y='fare',data= dftaxis,hue='payment')
# Out:
# <Axes: xlabel='color', ylabel='fare'>

# %%
#lmplot
#we can take here 4 variable also
sns.lmplot(x='distance',y='fare',data=dftaxis)

# %%
sns.lmplot(x='distance',y='fare',data=dftaxis,hue='payment',col='color')

# %%
flights=sns.load_dataset("flights")

flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
import seaborn as sns
flights = sns.load_dataset("flights")
flights = flights.pivot(index="month", columns="year",values="passengers")
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
flights = flights.pivot_table(index='month', columns='year', values='passengers', aggfunc='sum')
flights
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 flights = flights.pivot_table(index='month', columns='year', values='passengers', aggfunc='sum')
#       2 flights
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8579, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8562 @Substitution("")
#    8563 @Appender(_shared_docs["pivot_table"])
#    8564 def pivot_table(
#    (...)
#    8575     sort: bool = True,
#    8576 ) -> DataFrame:
#    8577     from pandas.core.reshape.pivot import pivot_table
# -> 8579     return pivot_table(
#    8580         self,
#    8581         values=values,
#    8582         index=index,
#    8583         columns=columns,
#    8584         aggfunc=aggfunc,
#    8585         fill_value=fill_value,
#    8586         margins=margins,
# ...

# %% [markdown]
# # Heatmap

# %%
fx = sns.heatmap(flights)
fx
# Out:
# <Axes: xlabel='year', ylabel='month'>
