# %% [markdown]
# # Boston house Data set

# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
bos=pd.read_csv('boston_dataset.csv')
bos
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
bos=pd.DataFrame(data=bos)
bos
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %% [markdown]
# # now start EDA process

# %%
bos.shape
# Out:
# (506, 14)

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'target'],
#       dtype='object')

# %%
bos.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# target     float64
# dtype: object

# %%
bos.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
 sns.heatmap(bos.isnull())
# Out:
# <Axes: >

# %%
bos.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
bos.skew()
# Out:
# CRIM       5.223149
# ZN         2.225666
# INDUS      0.295022
# CHAS       3.405904
# NOX        0.729308
# RM         0.403612
# AGE       -0.598963
# DIS        1.011781
# RAD        1.004815
# TAX        0.669956
# PTRATIO   -0.802325
# B         -2.890374
# LSTAT      0.906460
# target     1.108098
# dtype: float64

# %%
bos['ZN'].plot.box()
# Out:
# <Axes: >

# %%
bos['CRIM'].plot.box()
# Out:
# <Axes: >

# %%
#box plot together
bos.plot(kind='box',subplots=True,layout=(2,7))
# Out:
# CRIM          Axes(0.125,0.53;0.0945122x0.35)
# ZN         Axes(0.238415,0.53;0.0945122x0.35)
# INDUS      Axes(0.351829,0.53;0.0945122x0.35)
# CHAS       Axes(0.465244,0.53;0.0945122x0.35)
# NOX        Axes(0.578659,0.53;0.0945122x0.35)
# RM         Axes(0.692073,0.53;0.0945122x0.35)
# AGE        Axes(0.805488,0.53;0.0945122x0.35)
# DIS           Axes(0.125,0.11;0.0945122x0.35)
# RAD        Axes(0.238415,0.11;0.0945122x0.35)
# TAX        Axes(0.351829,0.11;0.0945122x0.35)
# PTRATIO    Axes(0.465244,0.11;0.0945122x0.35)
# B          Axes(0.578659,0.11;0.0945122x0.35)
# LSTAT      Axes(0.692073,0.11;0.0945122x0.35)
# target     Axes(0.805488,0.11;0.0945122x0.35)
# dtype: object

# %%
#removing outliers
from scipy.stats import zscore
z=np.abs(zscore(bos))
z
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0    0.419782  0.284830  1.287909  0.272599  0.144217  0.413672  0.120013
# 1    0.417339  0.487722  0.593381  0.272599  0.740262  0.194274  0.367166
# 2    0.417342  0.487722  0.593381  0.272599  0.740262  1.282714  0.265812
# 3    0.416750  0.487722  1.306878  0.272599  0.835284  1.016303  0.809889
# 4    0.412482  0.487722  1.306878  0.272599  0.835284  1.228577  0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.413229  0.487722  0.115738  0.272599  0.158124  0.439316  0.018673
# 502  0.415249  0.487722  0.115738  0.272599  0.158124  0.234548  0.288933
# 503  0.413447  0.487722  0.115738  0.272599  0.158124  0.984960  0.797449
# 504  0.407764  0.487722  0.115738  0.272599  0.158124  0.725672  0.736996
# 505  0.415000  0.487722  0.115738  0.272599  0.158124  0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT    target
# ...

# %%
#threshold for zscore value above 3 are considered outliers
threshold=3
print(np.where(z>3))
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#        200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#        220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#        277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#        357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#        380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#        416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#        437, 438, 445, 450, 454, 455, 456, 457, 466], dtype=int64), array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#         5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#         3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#         0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
# ...

# %%
z.iloc[55][1]
# Out:
# 3.375038763517294

# %%
z.iloc[466][11]
# Out:
# 3.669376372197529

# %%
# for check skewenes
bos['ZN'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
bos['CRIM'].plot.hist()
#little skeweness
# Out:
# <Axes: ylabel='Frequency'>

# %%
#now remove skewness
#bos['CRIM']=np.log(bos['CRIM'])
#bos['CRIM'].plot.hist()

# %%
from scipy.stats import boxcox
# 0 - log transform
# 0.5 - Square root transform
bos['CRIM']=boxcox(bos['CRIM'],0)

# %%
bos['CRIM'].plot.hist()
#here no skewness
# Out:
# <Axes: ylabel='Frequency'>

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'target'],
#       dtype='object')

# %%
plt.scatter(bos['B'],bos['target'])
plt.show()

# %%
plt.scatter(bos['CRIM'],bos['target'])
plt.show()

# %%
plt.scatter(bos['RM'],bos['target'])
plt.show()

# %%
#we can write like this also
x=bos['RM']
y=bos['target']
plt.scatter(x,y)
plt.show()

# %%
sns.pairplot(bos)
# Out:
# C:\Users\ww\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#plt figure
corr_hmap=bos.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %%
plt.scatter(bos['target'],bos['LSTAT'])
plt.show()

# %%
plt.scatter(bos['target'],bos['RM'])
plt.show()

# %%
#negative corelaated column we can drop
# drop LSAT 
bos.drop('LSTAT',axis=1,inplace=True)
# already dropped thats why give error

# %%
# LSTAT dropped Now
bos.head()
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0 -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1 -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2 -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3 -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4 -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  target
# 0     15.3  396.90    24.0
# 1     17.8  396.90    21.6
# 2     17.8  392.83    34.7
# 3     18.7  394.63    33.4
# 4     18.7  396.90    36.2

# %%
#removing outliers
bos_new = bos[(z<3).all(axis=1)]
bos_new
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  target
# 0       15.3  396.90    24.0
# 1       17.8  396.90    21.6
# ...

# %%
bos.shape
# Out:
# (506, 13)

# %%
bos_new.shape
# Out:
# (415, 13)

# %%
bos1=bos_new
bos1
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  target
# 0       15.3  396.90    24.0
# 1       17.8  396.90    21.6
# ...

# %%
x=bos1.iloc[:,0:-1]
x
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501 -2.770511   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502 -3.095111   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503 -2.800824   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504 -2.211009   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505 -3.048922   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B
# 0       15.3  396.90
# 1       17.8  396.90
# 2       17.8  392.83
# ...

# %%
x.head()
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0 -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1 -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2 -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3 -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4 -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B
# 0     15.3  396.90
# 1     17.8  396.90
# 2     17.8  392.83
# 3     18.7  394.63
# 4     18.7  396.90

# %%
y=bos1.iloc[:,-1]
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: target, dtype: float64

# %%
x.shape
# Out:
# (415, 12)

# %%
y.shape
# Out:
# (415,)

# %%
# now split data between training and testing
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (278, 12)

# %%
y_train.shape
# Out:
# (278,)

# %%
x_test.shape
# Out:
# (137, 12)

# %%
y_test.shape
# Out:
# (137,)

# %% [markdown]
# # Now aplied linear regression

# %%
lm=LinearRegression()

# %%
lm
# Out:
# LinearRegression()

# %%
# fit method used for training
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 4.14796426e-01, -9.48452702e-03, -4.06227602e-02, -8.85385515e-14,
#        -1.23983569e+01,  8.31144766e+00, -6.77907881e-02, -1.13441493e+00,
#         5.01745969e-02, -1.14702471e-02, -7.86910388e-01,  9.22717357e-03])

# %%
lm.intercept_
# Out:
# 1.885466646584888

# %%
lm.score(x_train,y_train)
# Out:
# 0.7450145138939896

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'target'],
#       dtype='object')

# %%
# now predict the value
pred=lm.predict(x_test)
print('Predicted Result price : ',pred)
print('Actual price',y_test)
# Out:
# Predicted Result price :  [20.52442424 14.50954987 31.48981889 18.38422384 13.11595168 20.74166358
#  17.31106356 25.10782451 29.63472112 10.80717631 17.72388147 15.66550921
#   8.98488733 24.2796744  28.0476132  10.66047743 25.72749894 27.39232049
#  24.82886327 14.00150342 21.74381609 19.10692104 23.56431589 12.02612149
#  21.95599491 21.65951382 31.75447852 27.59747081 22.12417845 25.11716752
#  32.44831628 14.71524841 13.54990408 26.20905344 15.60321561 15.05490348
#  26.86359361 22.35845603 13.86144763 18.99549243 17.0945682  18.05130457
#  20.53768755 26.7156161  17.09451963 26.13236614 19.94441974 19.53061132
#  17.73605627 24.45928944 20.77561576 19.08973639 39.75458281 13.43911029
#  19.02561668 22.10396188 18.67498499 41.20330795 20.14021397 18.15193296
#  26.50489232 16.78844208 24.55486022 27.9783275  14.51500777  5.34938429
#  34.18098705 19.63353383 19.10870329 22.45899667 35.32998138 19.93681787
#  24.22017841 24.67056111 15.35382945 22.52605265 16.4249922  17.9233105
# ...

# %% [markdown]
# # Metrics

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print('error')
print('mean_absolute_error :',mean_absolute_error(y_test,pred))
print('mean_squared_error :',mean_squared_error(y_test,pred))
print('root_mean_squared_error :',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# mean_absolute_error : 2.8280705019261423
# mean_squared_error : 25.67746985686854
# root_mean_squared_error : 5.067294135617996

# %%
#r2 score -> cofficient of determination 
#is the proportion of the variance in the dependent variable that is predictable from the independent value
#i.g change comming in y whenever xis being changed
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.5559219963471584

# %%
#predict the house price by providing the values
t=np.array([0.00632,18.0,2.31,0.0,0.538,6.575,65.2,4.0900,1.0,296.0,15.13,396.90])
t
# Out:
# array([6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#        6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.513e+01, 3.969e+02])

# %%
t.shape
# Out:
# (12,)

# %%
t=t.reshape(1,-1)
t
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.513e+01, 3.969e+02]])

# %%
t.shape
# Out:
# (1, 12)

# %%
lm.predict(t)
# Out:
# C:\Users\ww\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([28.95255644])

# %%
df=pd.DataFrame(pred)
df.to_csv('house_pred_submission.csv')

# %%
c=pd.read_csv('house_pred_submission.csv')
c
# Out:
#      Unnamed: 0          0
# 0             0  20.524424
# 1             1  14.509550
# 2             2  31.489819
# 3             3  18.384224
# 4             4  13.115952
# ..          ...        ...
# 132         132  23.524309
# 133         133   9.278236
# 134         134  24.722671
# 135         135  20.349625
# 136         136  19.340951
#
# [137 rows x 2 columns]
